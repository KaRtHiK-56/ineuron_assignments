# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# ans : True and False True = 1 and False = 0
#
# 2. What are the three different types of Boolean operators?
#
# ans : AND OR NOT
#
# 3. Make a list of each Boolean operator&#39;s truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate ).
#
# ans : AND
#  t t - 1
#  t f - 0
#  f t - 0
#  f f - 1
#
#  OR
#  t t - 1
#  t f - 1
#  f t - 1
#  f f - 0
#
#  NOT
#  t = 0
#  f = 1
#
# 4. What are the values of the following expressions?
# (5 > 4) and (3 == 5)
# not (5 > 4)
# (5 > 4) or (3 == 5)
# not ((5 > 4) or (3 == 5))
# (True and True) and (True == False)
# (not False) or (not True)
#
# ans :
# (5 > 4) and (3 == 5) = False
# not (5 > 4) = False
# (5 > 4) or (3 == 5) True
# not ((5 > 4) or (3 == 5)) = False
# (True and True) and (True == False) = False
# (not False) or (not True) = True
#
# 5. What are the six comparison operators?
#
# ans : > < >= <= != ==
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
#
# ans : == equal to as it checks for the condition as both is same or not if 5 == 5 :
#       = simply assigns a value to a variable  a = 1
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print(&#39;eggs&#39;)
# if spam &gt; 5:
# print(&#39;bacon&#39;)
# else:
# print(&#39;ham&#39;)
# print(&#39;spam&#39;)
# print(&#39;spam&#39;)
#
# ans : ham
#       spam
#       spam
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# ans :
# spam = int(input())
# if spam == 1 :
#     print("hello")
# elif spam == 2 :
#     print("howdy")
# else :
#     print("Greetings!")
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
# ans : CTRL + C
#
# 10. How can you tell the difference between break and continue?
#
# ans : break , if the condition is met it automatically out of the loop
#       continue , if the condition is met it automatically skips the current iteration and goes to the next statement
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#
# ans : all is same and prints the same output
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
# program that prints the numbers 1 to 10 using a while loop.
#
# ans : for loop
# for i in range (0,11):
#     print (i)
# while loop
# i = 0
# while i<=10 :
#     print(i)
#     i=i+1
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?
#
# ans : using the function name bacon()
