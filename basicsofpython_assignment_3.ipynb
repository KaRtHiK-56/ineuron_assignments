# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
# ans :
#      functions are used in a program to make it more readable and more easy to understand and reusability, functions makes program to follow bottom to top approach.it breaks the complex program it simple and easier piece and more readiable.
#
# 2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?
#
# ans :
#     when ever the function is defined in a program the program will execute all other statements untill or unless the function
# is called ,so the function gets executed when ever it is called.
#
# 3. What statement creates a function?
# ans :
#     def function_name():
#         statememt_1
#         statememt_2 .....
#     this is used to create a function
#
# 4. What is the difference between a function and a function call?
#
# ans :
#     when ever the function is created in a program the program will execute all other statements untill or unless the function
# is called , so defining a function is useless as it wont be executed unless it is called
#
# def function_name():
#         statememt_1
#         statememt_2
#
# function_name()
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# ans :  in a program we can create as many global scope and local scope depending on the program type.
#     types of scope : global , local , enclosed and builtin
#
# 6. What happens to variables in a local scope when the function call returns?
#
# ans :
#      when a function returns the local variable retains its value , ie. the variable gets occupies or destroyed so they cannot be using same local variable to a value again.
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# ans :
#      the return is a value that is used inside a function which gives a value when it is finished its execution. it can be any one of the four variable types: handle, integer, object, or string. yes , it is possible to have aexpression as a function
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# ans :
#     when a function does not have a return value , it does not give nothing when the program gets executed , like it wont display anything in output.
#
# 9. How do you make a function variable refer to the global variable?
#
# ans :
#     it is done using declarring the global keyword to the variable inside the function.
#
# 10. What is the data type of None?
#
# ans : nonetype, is the data type of None
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# ans:
#      i doubt there is no module like this , i dont know it can show error
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# ans :
#     This function can be called with spam.bacon()
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# ans :
#         error handling can be used to prevent a programme from crashing
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# ans :
#     The try block allows you to test a block of code for errors.if no error is present it get executed and returns somrthing and the except block enables you to handle the error that if occured in program and returns a reply of the error type.
